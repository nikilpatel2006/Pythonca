# %%
# 554 : 562

# %%
#q1

# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2
import pandas as pd

# %%
# Q1
df= pd.read_csv('IPL2024_Data (1).csv')

# %%
null_values = df.isnull().sum().sum()
if null_values == 0:
    print("The data frame contains no null values.")
else:
    print(f"The data frame contains {null_values} null values.")

# Number of rows and columns
rows, columns = df.shape
print(f"The data frame has {rows} rows and {columns} columns.")

# Data types of each column
data_types = df.dtypes
print("Data types of each column:")
print(data_types)
# Out:
# The data frame contains no null values.
# The data frame has 1172 rows and 25 columns.
# Data types of each column:
# Year                   object
# Player_Name            object
# Matches_Batted         object
# Not_Outs               object
# Runs_Scored            object
# Highest_Score          object
# Batting_Average        object
# Balls_Faced            object
# Batting_Strike_Rate    object
# Centuries              object
# Half_Centuries         object
# Fours                  object
# Sixes                  object
# Catches_Taken          object
# Stumpings              object
# Matches_Bowled         object
# Balls_Bowled           object
# Runs_Conceded          object
# Wickets_Taken          object
# Best_Bowling_Match     object
# Bowling_Average        object
# Economy_Rate           object
# Bowling_Strike_Rate    object
# Four_Wicket_Hauls      object
# Five_Wicket_Hauls      object
# dtype: object

# %%
if df.isnull().values.any():
    print("Data frame contains null values.")
else:
    print("Data frame is valid with no null values.")
# Out:
# Data frame is valid with no null values.

# %%
rows, columns = df.shape
print(f"Number of rows: {rows}")
print(f"Number of columns: {columns}")
# Out:
# Number of rows: 1172
# Number of columns: 25

# %%
# Q2

# %%
df_cleaned= pd.read_csv('IPL2024_Data_Cleaned.csv')

# %%
df_ipl = df_cleaned[['Year','Player_Name', 'Runs_Scored', 'Catches_Taken', 'Wickets_Taken']]
df_ipl
# Out:
#       Year      Player_Name  Runs_Scored  Catches_Taken  Wickets_Taken
# 0     2024  Ruturaj Gaikwad           61              0              0
# 1     2023  Ruturaj Gaikwad          590             17              0
# 2     2022  Ruturaj Gaikwad          368              4              0
# 3     2021  Ruturaj Gaikwad          635              6              0
# 4     2020  Ruturaj Gaikwad          204              4              0
# ...    ...              ...          ...            ...            ...
# 1125  2023  Mayank Markande           21              1             12
# 1126  2022  Mayank Markande            0              2              1
# 1127  2021  Mayank Markande            0              0              0
# 1128  2019  Mayank Markande            6              0              1
# 1129  2018  Mayank Markande           21              3             15
#
# [1130 rows x 5 columns]

# %%
# Save the new DataFrame to a CSV file
df_ipl.to_csv('IPL_Player_Performance.csv', index=False)

# %%
# Find the player with maximum runs scored
max_runs_player = df_ipl.loc[df_ipl['Runs_Scored'].idxmax()]

# Find the player with maximum catches taken
max_catches_player = df_ipl.loc[df_ipl['Catches_Taken'].idxmax()]

# Find the player with maximum wickets taken
max_wickets_player = df_ipl.loc[df_ipl['Wickets_Taken'].idxmax()]

print("Player with maximum runs scored:")
print(max_runs_player)

print("\nPlayer with maximum catches taken:")
print(max_catches_player)

print("\nPlayer with maximum wickets taken:")
print(max_wickets_player)
# Out:
# Player with maximum runs scored:
# Player_Name      Virat Kohli
# Runs_Scored              973
# Catches_Taken              6
# Wickets_Taken              0
# Name: 910, dtype: object
#
# Player with maximum catches taken:
# Player_Name      Rishabh Pant
# Runs_Scored               488
# Catches_Taken              18
# Wickets_Taken               0
# Name: 116, dtype: object
#
# Player with maximum wickets taken:
# Player_Name      Harshal Patel
# Runs_Scored                 59
# Catches_Taken                3
# Wickets_Taken               32
# Name: 763, dtype: object

# %%
#Q3

# %%
# Filter the data for Ravi 
Mohsin_Khan_df = df[df['Player_Name'] == 'Mohsin Khan']
Mohsin_Khan_df
# Out:
#      Year  Player_Name Matches_Batted Not_Outs Runs_Scored Highest_Score  \
# 553  2024  Mohsin Khan              1        0           0             0
# 554  2023  Mohsin Khan              5        0           0             0
# 555  2022  Mohsin Khan              9        2          23           13*
#
#     Batting_Average Balls_Faced Batting_Strike_Rate Centuries  ...  \
# 553               0           0                   0         0  ...
# 554            0.00           7                0.00         0  ...
# 555           23.00          16              143.75         0  ...
#
#     Matches_Bowled Balls_Bowled Runs_Conceded Wickets_Taken  \
# 553              1           24            45             1
# 554              5           60           107             3
# 555              9          198           197            14
#
#     Best_Bowling_Match Bowling_Average Economy_Rate Bowling_Strike_Rate  \
# 553               1/45              45        11.25                  24
# ...

# %%
# Mohsin Khan has been playing for 2022 to 2024, ipl franchise have shown the trust on him by retaining him for continously three year.
# Balling average have been worst year by year and also he also not able to take wicket that's why team not giving much chances in game.

# %%
# Plotting Mohsin Khan performance over the years

# Plot Bowling Average
plt.plot(Mohsin_Khan_df['Year'], Mohsin_Khan_df['Bowling_Average'], marker='d', label='Bowling_Average')
plt.title('Mohsin Khan IPL Performance Over the Years')
plt.xlabel('Year')
plt.ylabel('Count')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Plot Wickets Taken

plt.plot(Mohsin_Khan_df['Year'], Mohsin_Khan_df['Wickets_Taken'], marker='o', label='Wickets Taken')
plt.title('Mohsin Khan IPL Performance Over the Years')
plt.xlabel('Year')
plt.ylabel('Count')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Plot Matches Batted
plt.plot(Mohsin_Khan_df['Year'], Mohsin_Khan_df['Matches_Batted'], marker='o', label='Matches_Batted', linestyle = '--')
plt.title('Mohsin Khan IPL Performance Over the Years')
plt.xlabel('Year')
plt.ylabel('Count')
plt.legend()
plt.grid(True)
plt.show()

# %%
#q4
Mayank_Yadav_df = df[df['Player_Name'] == 'Mayank Yadav']
Mayank_Yadav_df
# Out:
#          Year   Player_Name Matches_Batted  Not_Outs Runs_Scored  \
# 552  No stats  Mayank Yadav       No stats  No stats    No stats
#
#     Highest_Score Batting_Average Balls_Faced Batting_Strike_Rate Centuries  \
# 552      No stats        No stats    No stats            No stats  No stats
#
#      ... Matches_Bowled Balls_Bowled Runs_Conceded Wickets_Taken  \
# 552  ...       No stats     No stats      No stats      No stats
#
#     Best_Bowling_Match Bowling_Average Economy_Rate Bowling_Strike_Rate  \
# 552           No stats        No stats     No stats            No stats
#
#     Four_Wicket_Hauls Five_Wicket_Hauls
# 552          No stats          No stats
#
# [1 rows x 25 columns]

# %%
Mohsin_Khan_df = df[df['Player_Name'] == 'Mohsin Khan']
Mohsin_Khan_df
# Out:
#      Year  Player_Name Matches_Batted Not_Outs Runs_Scored Highest_Score  \
# 553  2024  Mohsin Khan              1        0           0             0
# 554  2023  Mohsin Khan              5        0           0             0
# 555  2022  Mohsin Khan              9        2          23           13*
#
#     Batting_Average Balls_Faced Batting_Strike_Rate Centuries  ...  \
# 553               0           0                   0         0  ...
# 554            0.00           7                0.00         0  ...
# 555           23.00          16              143.75         0  ...
#
#     Matches_Bowled Balls_Bowled Runs_Conceded Wickets_Taken  \
# 553              1           24            45             1
# 554              5           60           107             3
# 555              9          198           197            14
#
#     Best_Bowling_Match Bowling_Average Economy_Rate Bowling_Strike_Rate  \
# 553               1/45              45        11.25                  24
# ...

# %%
Ravi_Bishnoi_df = df[df['Player_Name'] == 'Ravi Bishnoi']
Ravi_Bishnoi_df
# Out:
#      Year   Player_Name Matches_Batted Not_Outs Runs_Scored Highest_Score  \
# 556  2024  Ravi Bishnoi              1        0           0             0
# 557  2023  Ravi Bishnoi             15        4          20             5
# 558  2022  Ravi Bishnoi             14        1           0            0*
# 559  2021  Ravi Bishnoi              9        0           1             1
# 560  2020  Ravi Bishnoi             14        2           7            6*
#
#     Batting_Average Balls_Faced Batting_Strike_Rate Centuries  ...  \
# 556               0           0                   0         0  ...
# 557            6.67          27               74.07         0  ...
# 558               0           1                0.00         0  ...
# 559            1.00           4               25.00         0  ...
# 560            7.00          12               58.33         0  ...
#
#     Matches_Bowled Balls_Bowled Runs_Conceded Wickets_Taken  \
# ...

# %%
player1 = 'Mayank Yadav'
player2 = 'Mohsin Khan'
player3 = 'Ravi Bishnoi'

# Filter the data for the players
df_player1 = df[df['Player_Name'] == player1]
df_player2 = df[df['Player_Name'] == player2]
df_player3 = df[df['Player_Name'] == player3]

# %%
# Story on the camparison on the performnce of Ravi Bishnoi, Mohsin Khan, & Mayank Yadav.
# Ravi Bishnoi is a better player , which have can also be seen in the ipl stats.
# Ravi had too much fluctuation in his ipl performance which make the team management confused
# wheather to take him in the game or not. But Mohsin had a direct downfall in his ipl career.
# And Mayank Yadav had never played the match, so there the no data to talk about him.

# %%
# Plotting the performance of the players over the years

# Plot Runs Scored
plt.plot(df_player1['Year'], df_player1['Runs_Scored'], marker='o', label=f' {player1}')
plt.plot(df_player2['Year'], df_player2['Runs_Scored'], marker='o', label=f' {player2}')
plt.plot(df_player3['Year'], df_player3['Runs_Scored'], marker='o', label=f' {player3}')
plt.title('Comparison of IPL Performance Over the Years')
plt.xlabel('Year')
plt.ylabel('Runs Scored')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Plot Balls bowled
plt.plot(df_player1['Year'], df_player1['Balls_Bowled'], marker='o', label=f' {player1}')
plt.plot(df_player2['Year'], df_player2['Balls_Bowled'], marker='x', label=f' {player2}')
plt.plot(df_player3['Year'], df_player3['Balls_Bowled'], marker='d', label=f' {player3}')
plt.title('Comparison of IPL Performance Over the Years')
plt.xlabel('Year')
plt.ylabel('Balls Bowled')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Plot Catches Taken
plt.plot(df_player1['Year'], df_player1['Catches_Taken'], marker='d', linestyle='--', label=f' {player1}')
plt.plot(df_player2['Year'], df_player2['Catches_Taken'], marker='x', linestyle='--', label=f' {player2}')
plt.plot(df_player3['Year'], df_player3['Catches_Taken'], marker='o', linestyle='--', label=f' {player3}')
plt.title('Comparison of IPL Performance Over the Years')
plt.xlabel('Year')
plt.ylabel('Catches Taken')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Plot Wickets Taken
plt.plot(df_player1['Year'], df_player1['Wickets_Taken'], marker='d', linestyle='--', label=f' {player1}')
plt.plot(df_player2['Year'], df_player2['Wickets_Taken'], marker='s', linestyle='-.', label=f' {player2}')
plt.plot(df_player3['Year'], df_player3['Wickets_Taken'], marker='s', linestyle='-.', label=f' {player3}')
plt.title('Comparison of IPL Performance Over the Years')
plt.xlabel('Year')
plt.ylabel('Wickets Taken')
plt.legend()
plt.grid(True)
plt.show()

# %%
#q5

# %%
df_ipl
# Out:
#       Year      Player_Name  Runs_Scored  Catches_Taken  Wickets_Taken
# 0     2024  Ruturaj Gaikwad           61              0              0
# 1     2023  Ruturaj Gaikwad          590             17              0
# 2     2022  Ruturaj Gaikwad          368              4              0
# 3     2021  Ruturaj Gaikwad          635              6              0
# 4     2020  Ruturaj Gaikwad          204              4              0
# ...    ...              ...          ...            ...            ...
# 1125  2023  Mayank Markande           21              1             12
# 1126  2022  Mayank Markande            0              2              1
# 1127  2021  Mayank Markande            0              0              0
# 1128  2019  Mayank Markande            6              0              1
# 1129  2018  Mayank Markande           21              3             15
#
# [1130 rows x 5 columns]

# %%
yearly_total_data = df_ipl.groupby('Year').agg({
    'Runs_Scored': 'sum',
    'Catches_Taken': 'sum',
    'Wickets_Taken': 'sum'
}).reset_index()

# Display the yearly summary
print(yearly_total_data)
# Out:
#     Year  Runs_Scored  Catches_Taken  Wickets_Taken
# 0   2008         1907             55             39
# 1   2009         2191             55             57
# 2   2010         2233             56             63
# 3   2011         3395             69             95
# 4   2012         4104             94            120
# 5   2013         5076            135            191
# 6   2014         6290            148            260
# 7   2015         6936            188            224
# 8   2016         8430            166            251
# 9   2017         8558            217            349
# 10  2018        11823            311            425
# 11  2019        13056            354            443
# 12  2020        14231            341            489
# 13  2021        14956            370            537
# 14  2022        21161            561            677
# 15  2023        22914            554            745
# 16  2024         2185             60             74

# %%
# story on overall ipl data from 2008 to 2024
# 2023 have been a most interesting year as the total run scored & total wickets taken are the highest and also
# the catches taken are good. The most boring year is 2008 where the all catches, wickets, runs are too low.
# the data show that the performance in ipl have been going better year by year, except 2017,2021,2024 where the performance have little degradation.

# %%
# Plot Total Catches Taken Runs Scored

plt.plot(yearly_total_data['Year'], yearly_total_data['Runs_Scored'], marker='o', linestyle='-.', label= 'Runs Scored', color = 'red')
plt.title('Comparison of IPL Performance Over the Years')
plt.xlabel('Year')
plt.ylabel('Count')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Plot Total Catches Taken
plt.plot(yearly_total_data['Year'], yearly_total_data['Catches_Taken'], marker='s', linestyle='--', label='Catches Taken', color = 'purple')
plt.title('Comparison of IPL Performance Over the Years')
plt.xlabel('Year')
plt.ylabel('Count')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Plot Total Wickets Taken
plt.plot(yearly_total_data['Year'], yearly_total_data['Wickets_Taken'], marker='d', linestyle=':', label='Wickets Taken', color = 'green')
plt.title('Comparison of IPL Performance Over the Years')
plt.xlabel('Year')
plt.ylabel('Count')
plt.legend()
plt.grid(True)
plt.show()

# %%
#All the wicket taken, run scored, and catches taken in one songle graph.

plt.plot(yearly_total_data['Year'], yearly_total_data['Wickets_Taken'], marker='d', linestyle=':', label='Wickets Taken', color = 'black')
plt.plot(yearly_total_data['Year'], yearly_total_data['Catches_Taken'], marker='s', linestyle='--', label='Catches Taken', color = 'yellow')
plt.plot(yearly_total_data['Year'], yearly_total_data['Runs_Scored'], marker='o', linestyle='-.', label= 'Runs Scored', color = 'red')
plt.title('Comparison of IPL Performance Over the Years')
plt.xlabel('Year')
plt.ylabel('Count')
plt.legend()
plt.grid(True)
plt.show()
